# %%
from glob import glob
from visualize_predictions import visualize_predictions
# Out:
# Using TensorFlow backend.

# %%
visualize_predictions("saved_models/cqt_e7/cqt_e7.h5", glob(r"processed/base/train/" + r"/*.tfrecord"))
# Out:
# Id: b'03_SS1-68-E_comp-seg00'
# Id: b'03_SS1-68-E_comp-seg01'
# Id: b'03_SS1-68-E_comp-seg02'
# Id: b'03_SS1-68-E_comp-seg03'
# Id: b'03_SS1-68-E_comp-seg04'
# Id: b'03_SS1-68-E_comp-seg05'
# Id: b'03_SS1-68-E_comp-seg06'
# Id: b'03_SS1-68-E_comp-seg07'
