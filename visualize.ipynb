# %%
from glob import glob
from visualize_predictions import visualize_predictions
# Out:
# Using TensorFlow backend.

# %%
visualize_predictions("saved_models/cqt_base_model/cqt_base_model.h5", glob(r"processed/base/train/" + r"/*.tfrecord"))
# Out:
# Id: b'03_SS1-68-E_comp-seg00'
# Id: b'03_SS1-68-E_comp-seg01'
# Id: b'03_SS1-68-E_comp-seg02'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 visualize_predictions("saved_models/cqt_base_model/cqt_base_model.h5", glob(r"processed/base/train/" + r"/*.tfrecord"))
#
# File /nfs/home/bernardo.florencio/github/pitch/visualize_predictions.py:56, in visualize_predictions(saved_model_path, data_path_list)
#      54 plt.show()
#      55 if input(".") == "x":
# ---> 56     exit()
#
# NameError: name 'exit' is not defined
