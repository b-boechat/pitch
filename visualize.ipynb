# %%
from glob import glob
from visualize_predictions import visualize_predictions
# Out:
# Using TensorFlow backend.

# %%
visualize_predictions("saved_models/fls_fw11/fls_fw11.h5", glob(r"processed/fls_fw11/val/" + r"/*.tfrecord"))
# Out:
# Id: b'02_Rock1-90-C#_comp-seg00'
# Id: b'02_Rock1-90-C#_comp-seg01'
# Id: b'02_Rock1-90-C#_comp-seg02'
# Id: b'02_Rock1-90-C#_comp-seg03'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 visualize_predictions("saved_models/fls_fw11/fls_fw11.h5", glob(r"processed/fls_fw11/val/" + r"/*.tfrecord"))
#
# File /nfs/home/bernardo.florencio/github/pitch/visualize_predictions.py:56, in visualize_predictions(saved_model_path, data_path_list)
#      54 plt.show()
#      55 if input(".") == "x":
# ---> 56     exit()
#
# NameError: name 'exit' is not defined
