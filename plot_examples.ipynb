# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
from test_saved_model import plot_examples

plot_examples("saved_models/trained_lr_e3.h5")
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
#       2 os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
#       3 from test_saved_model import plot_examples
# ----> 5 plot_examples("saved_models/trained_lr_e3.h5")
#
# File /nfs/home/bernardo.florencio/github/pitch/test_saved_model.py:42, in plot_examples(saved_model_path)
#      39 pred_X_contours, pred_X_notes, pred_X_onsets = pred["X_contours"][0].transpose(), pred["X_notes"][0].transpose(), pred["X_onsets"][0].transpose()
#      41 plt.figure()
# ---> 42 librosa.display.specshow(X_cqt, sr=AUDIO_SAMPLE_RATE, x_axis='time', y_axis='cqt_hz',
#      43     hop_length=CQT_HOP_LENGTH, fmin=MINIMUM_ANNOTATION_FREQUENCY, bins_per_octave=CONTOURS_BINS_PER_OCTAVE, tuning=0.0)
#      44 plt.figure()
# ...
