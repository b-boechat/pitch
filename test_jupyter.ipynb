# %%
from evaluate_model import mir_evaluate_and_save

mir_evaluate_and_save("cqt_e6", "val", onset_threshold=0.7, frame_threshold=0.5)
# Out:
# Using TensorFlow backend.
# {'learning_rate': 1e-06, 'label_smoothing': 0.2, 'buffer_size': 100, 'batch_size': 32, 'onset_positive_weight': 0.95, 'epochs': 150, 'data_base_dir': 'base'}
# [{'split_name': 'val', 'onset_threshold': 0.7, 'frame_threshold': 0.5}]
# target_pitches: [311.12698372 207.65234879 277.18263098 233.08188076 207.65234879
#  277.18263098 207.65234879 207.65234879 277.18263098 207.65234879
#  207.65234879 207.65234879 349.22823143 277.18263098 207.65234879
#  138.59131549 207.65234879 138.59131549 207.65234879 138.59131549
#  207.65234879 207.65234879 349.22823143 277.18263098 207.65234879
#  138.59131549 138.59131549 138.59131549 349.22823143 277.18263098
#  207.65234879 138.59131549 138.59131549 138.59131549 207.65234879
#  184.99721136 184.99721136 311.12698372 277.18263098 184.99721136
#  138.59131549 233.08188076 207.65234879 184.99721136 184.99721136
#  277.18263098 138.59131549 184.99721136 184.99721136 277.18263098
# ...
